# %% [markdown]
# <a href="https://colab.research.google.com/github/gandhionthehub/PrrPrr1/blob/main/gissa_28_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
from IPython.display import display, HTML
import sys #funkar i VS

#for i in range(1,10):
#print(random.randint(1,20))

pc = random.randint(1,10)
print("Välj ett heltal mellan 1-10.")
user = int(input())
print(f"Du valde: {user}")

if user < 1:
  print("Är du dum? Under 1?")
if user > 10:
  print("\033[1;91mDu fuskade...\033[0m")
  exit

print(f"Datorn valde: {pc}")

if pc == user:
  print(f"Du gissade rätt! :)")
else:
  print(f"Try again...")




if pc < user:
  print("Gissningen var för hög.")
else:
  print("Gissningen var för låg")
# Out:
# Välj ett heltal mellan 1-10.
# 6
# Du valde: 6
# Datorn valde: 1
# Try again...
# Gissningen är för hög.

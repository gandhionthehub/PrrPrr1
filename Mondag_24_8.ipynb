# %% [markdown]
# <a href="https://colab.research.google.com/github/gandhionthehub/PrrPrr1/blob/main/Mondag_24_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
namn_str = "bob"
nummer_int = 420
decimal_float = 420.69
binär_bool = True #1
binär_bool2 = False #0

print(namn_str)
print(nummer_int)
print(decimal_float)
print(binär_bool)
print(binär_bool2)

print(type(namn_str))
print(type(nummer_int))
print(type(decimal_float))
print(type(binär_bool))
print(type(binär_bool2))

poäng = 0
print(poäng)
poäng += 1
print(poäng)
poäng += 1
print(poäng)
poäng += 1
print(poäng)

divider = "-TrueTrue problem-"
print(divider)

print(True + True) # eftersom True = 1 => 1 + 1 = 2
# Out:
# bob
# 420
# 420.69
# True
# False
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'bool'>
# 0
# 1
# 2
# 3
# -TrueTrue problem-
# 2

# %% [markdown]
# <a href="https://colab.research.google.com/github/gandhionthehub/PrrPrr1/blob/main/fredag_20_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world!")
name = input("Skriv ditt namn: ")
print("Hej", name)
# Out:
# Hello world!
# Skriv ditt namn: big bob
# Hej big bob
